# %% [markdown]
# # WEEK 5 - PROJECT 1

# %%
import warnings
warnings.simplefilter('ignore', FutureWarning)

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
capetown = pd.read_csv('C:\\Users\\Millen\\Desktop\\CapeTown_CPT_2014.csv')
capetown
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0      2014-1-1                28                 23                18
# 1      2014-1-2                28                 23                18
# 2      2014-1-3                27                 23                19
# 3      2014-1-4                27                 22                18
# 4      2014-1-5                26                 22                18
# ..          ...               ...                ...               ...
# 360  2014-12-27                24                 20                15
# 361  2014-12-28                28                 21                15
# 362  2014-12-29                29                 24                18
# 363  2014-12-30                27                 23                19
# 364  2014-12-31                32                 26                19
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
capetown = capetown.rename(columns={'WindDirDegrees<br />' : 'WindDirDegrees'})
capetown
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0      2014-1-1                28                 23                18
# 1      2014-1-2                28                 23                18
# 2      2014-1-3                27                 23                19
# 3      2014-1-4                27                 22                18
# 4      2014-1-5                26                 22                18
# ..          ...               ...                ...               ...
# 360  2014-12-27                24                 20                15
# 361  2014-12-28                28                 21                15
# 362  2014-12-29                29                 24                18
# 363  2014-12-30                27                 23                19
# 364  2014-12-31                32                 26                19
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
capetown.tail()
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 360  2014-12-27                24                 20                15
# 361  2014-12-28                28                 21                15
# 362  2014-12-29                29                 24                18
# 363  2014-12-30                27                 23                19
# 364  2014-12-31                32                 26                19
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 360          15              13             10            77              61
# 361          15              14             12            82              57
# 362          17              15             14            78              59
# 363          17              16             15            78              60
# 364          18              16             15            73              55
#
#       Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# ...

# %%
capetown.describe()
# Out:
#        Max TemperatureC  Mean TemperatureC  Min TemperatureC  Dew PointC  \
# count        365.000000         365.000000        365.000000  365.000000
# mean          22.684932          17.567123         12.509589   13.783562
# std            4.839957           4.148880          4.288118    3.018215
# min           11.000000           7.000000          1.000000    5.000000
# 25%           19.000000          14.000000          9.000000   12.000000
# 50%           23.000000          18.000000         13.000000   14.000000
# 75%           26.000000          21.000000         16.000000   16.000000
# max           37.000000          28.000000         22.000000   21.000000
#
#        MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# count      365.000000     365.000000    365.000000      365.000000
# mean        11.583562       9.134247     87.452055       68.758904
# std          3.289469       3.892943      7.311817        8.740581
# ...

# %%
capetown['Dew PointC']
# Out:
# 0      19
# 1      19
# 2      19
# 3      19
# 4      17
#        ..
# 360    15
# 361    15
# 362    17
# 363    17
# 364    18
# Name: Dew PointC, Length: 365, dtype: int64

# %%
capetown[155:200]
# Out:
#           Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 155   2014-6-5                13                 10                 7
# 156   2014-6-6                16                 11                 6
# 157   2014-6-7                19                 11                 3
# 158   2014-6-8                17                 13                 8
# 159   2014-6-9                11                  8                 6
# 160  2014-6-10                14                  9                 5
# 161  2014-6-11                17                  9                 2
# 162  2014-6-12                18                 10                 2
# 163  2014-6-13                24                 13                 2
# 164  2014-6-14                16                 14                13
# 165  2014-6-15                17                 15                13
# 166  2014-6-16                16                 12                 8
# ...

# %%
capetown[capetown['Max TemperatureC'] > 20].tail()
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 360  2014-12-27                24                 20                15
# 361  2014-12-28                28                 21                15
# 362  2014-12-29                29                 24                18
# 363  2014-12-30                27                 23                19
# 364  2014-12-31                32                 26                19
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 360          15              13             10            77              61
# 361          15              14             12            82              57
# 362          17              15             14            78              59
# 363          17              16             15            78              60
# 364          18              16             15            73              55
#
#       Min Humidity  ...   Max VisibilityKm   Mean VisibilityKm  \
# ...

# %%
capetown[capetown['Max TemperatureC'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Date, Max TemperatureC, Mean TemperatureC, Min TemperatureC, Dew PointC, MeanDew PointC, Min DewpointC, Max Humidity,  Mean Humidity,  Min Humidity,  Max Sea Level PressurehPa,  Mean Sea Level PressurehPa,  Min Sea Level PressurehPa,  Max VisibilityKm,  Mean VisibilityKm,  Min VisibilitykM,  Max Wind SpeedKm/h,  Mean Wind SpeedKm/h,  Max Gust SpeedKm/h, Precipitationmm,  CloudCover,  Events, WindDirDegrees]
# Index: []
#
# [0 rows x 23 columns]

# %%
capetown.max(axis = 0)
# Out:
# Date                           2014-9-9
# Max TemperatureC                     37
# Mean TemperatureC                    28
# Min TemperatureC                     22
# Dew PointC                           21
# MeanDew PointC                       20
# Min DewpointC                        18
# Max Humidity                        100
#  Mean Humidity                       88
#  Min Humidity                        78
#  Max Sea Level PressurehPa         1036
#  Mean Sea Level PressurehPa        1034
#  Min Sea Level PressurehPa         1033
#  Max VisibilityKm                  31.0
#  Mean VisibilityKm                 31.0
#  Min VisibilitykM                  31.0
#  Max Wind SpeedKm/h                  58
#  Mean Wind SpeedKm/h                 43
#  Max Gust SpeedKm/h                76.0
# Precipitationmm                   59.94
#  CloudCover                         7.0
# WindDirDegrees                  9<br />
# dtype: object

# %%
print(capetown['Max TemperatureC'].max())
print(max(capetown['Max TemperatureC']))
# Out:
# 37
# 37

# %%
x =capetown["Min TemperatureC"]/100
x
# Out:
# 0      0.18
# 1      0.18
# 2      0.19
# 3      0.18
# 4      0.18
#        ...
# 360    0.15
# 361    0.15
# 362    0.18
# 363    0.19
# 364    0.19
# Name: Min TemperatureC, Length: 365, dtype: float64

# %%
y = capetown["Max TemperatureC"]. apply (np.sqrt)
y
# Out:
# 0      5.291503
# 1      5.291503
# 2      5.196152
# 3      5.196152
# 4      5.099020
#          ...
# 360    4.898979
# 361    5.291503
# 362    5.385165
# 363    5.196152
# 364    5.656854
# Name: Max TemperatureC, Length: 365, dtype: float64

# %%
p = capetown["Mean TemperatureC"]. apply ( lambda d: d**2)
p
# Out:
# 0      529
# 1      529
# 2      529
# 3      484
# 4      484
#       ...
# 360    400
# 361    441
# 362    576
# 363    529
# 364    676
# Name: Mean TemperatureC, Length: 365, dtype: int64

# %%
capetown['ValueNorm'] = capetown['Max TemperatureC']/capetown['Max TemperatureC']. max ()
capetown
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0      2014-1-1                28                 23                18
# 1      2014-1-2                28                 23                18
# 2      2014-1-3                27                 23                19
# 3      2014-1-4                27                 22                18
# 4      2014-1-5                26                 22                18
# ..          ...               ...                ...               ...
# 360  2014-12-27                24                 20                15
# 361  2014-12-28                28                 21                15
# 362  2014-12-29                29                 24                18
# 363  2014-12-30                27                 23                19
# 364  2014-12-31                32                 26                19
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
capetown.sort_values(by = 'Max TemperatureC', ascending = True, inplace = True)
capetown
# Out:
#           Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 159   2014-6-9                11                  8                 6
# 186   2014-7-6                12                  9                 4
# 155   2014-6-5                13                 10                 7
# 185   2014-7-5                13                 10                 7
# 239  2014-8-28                13                 10                 7
# ..         ...               ...                ...               ...
# 99   2014-4-10                35                 25                15
# 30   2014-1-31                35                 28                20
# 46   2014-2-16                36                 28                20
# 100  2014-4-11                36                 26                15
# 101  2014-4-12                37                 26                16
#
#      Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity  Mean Humidity  \
# ...

# %% [markdown]
# #When choosing the best days to go for a vacation, high temperatures would be convenient and favorable.
# #For this reason, I am going to find the date range that has high temperatures, preferrrably 25 degrees and above.

# %%
summer = capetown[(capetown['Mean TemperatureC'] >= 25)]
summer
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 20    2014-1-21                31                 25                19
# 29    2014-1-30                31                 26                21
# 30    2014-1-31                35                 28                20
# 44    2014-2-14                33                 26                19
# 45    2014-2-15                33                 28                22
# 46    2014-2-16                36                 28                20
# 47    2014-2-17                29                 26                22
# 48    2014-2-18                31                 27                22
# 55    2014-2-25                33                 26                19
# 56    2014-2-26                34                 27                20
# 99    2014-4-10                35                 25                15
# 100   2014-4-11                36                 26                15
# ...

# %% [markdown]
# #According to reasearch/Google, Summer weather in South Africa lasts from October to March.

# %%
summer1 = summer.sort_values(by='Mean TemperatureC')
summer1
# Out:
#            Date  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 20    2014-1-21                31                 25                19
# 99    2014-4-10                35                 25                15
# 29    2014-1-30                31                 26                21
# 44    2014-2-14                33                 26                19
# 47    2014-2-17                29                 26                22
# 55    2014-2-25                33                 26                19
# 100   2014-4-11                36                 26                15
# 101   2014-4-12                37                 26                16
# 102   2014-4-13                34                 26                18
# 364  2014-12-31                32                 26                19
# 48    2014-2-18                31                 27                22
# 56    2014-2-26                34                 27                20
# ...

# %%
# %matplotlib inline

# %%
summer1['Mean TemperatureC'].plot(grid=True)
plt.xlabel('Date')
plt.ylabel('Mean TemperatureC')
plt.title('Summer Mean Temperature')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
